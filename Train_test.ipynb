# %% [markdown]
# # TRAINING

# %%
# !python coco2yolo.py -i '/drive0-storage/robot_pose/HumanoidRobotPoseEstimation/dataset/hrp/merge_test_2.json' -s '/drive0-storage/robot_pose/HumanoidRobotPoseEstimation/dataset/hrp/images/' -t 'yolo_robot_pose_merge' -n 'test'
# !python coco2yolo.py -i '/drive0-storage/robot_pose/HumanoidRobotPoseEstimation/dataset/hrp/merge_val_2.json' -s '/drive0-storage/robot_pose/HumanoidRobotPoseEstimation/dataset/hrp/images/' -t 'yolo_robot_pose_merge' -n 'val'
# !python coco2yolo.py -i '/drive0-storage/robot_pose/HumanoidRobotPoseEstimation/dataset/hrp/merge_train_2.json' -s '/drive0-storage/robot_pose/HumanoidRobotPoseEstimation/dataset/hrp/images/' -t 'yolo_robot_pose_merge' -n 'train'
# Out:
# ...
# 100%|█████████████████████████████████████| 1848/1848 [00:00<00:00, 5945.92it/s]

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/riset/.netrc
# True

# %%
# !python train.py --data data/robot_kpts.yaml --cfg cfg/yolov7-w6-robot-pose.yaml --weights weights/yolov7-w6-pose.pt --batch-size 8 --kpt-label --device 0 --name yolov7-pose-merge --hyp data/hyp.pose.yaml --epochs 150
# Out:
# fatal: ambiguous argument 'pose-6-keypoint..origin/master': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
# github: Command 'git rev-list pose-6-keypoint..origin/master --count' returned non-zero exit status 128.
# requirements: matplotlib>=3.2.2 not found and is required by YOLOv5, attempting auto-update...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# requirements: tqdm>=4.41.0 not found and is required by YOLOv5, attempting auto-update...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# requirements: tensorboard>=2.4.1 not found and is required by YOLOv5, attempting auto-update...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# requirements: seaborn>=0.11.0 not found and is required by YOLOv5, attempting auto-update...
# ...

# %%
# !python test.py --data data/robot_kpts.yaml --img 640 --batch 32 --conf 0.001 --iou 0.65 --device 0 --weights runs/train/yolov7-pose-merge/weights/best.pt --name yolov7_640_val
# Out:
# Namespace(weights=['runs/train/yolov7-pose-merge/weights/best.pt'], data='data/robot_kpts.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_txt_tidl=False, tidl_load=False, dump_img=False, save_hybrid=False, save_conf=False, save_json=False, save_json_kpt=False, project='runs/test', name='yolov7_640_val', exist_ok=False, kpt_label=False, flip_test=False)
# requirements: matplotlib>=3.2.2 not found and is required by YOLOv5, attempting auto-update...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# requirements: tqdm>=4.41.0 not found and is required by YOLOv5, attempting auto-update...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# requirements: seaborn>=0.11.0 not found and is required by YOLOv5, attempting auto-update...
# Defaulting to user installation because normal site-packages is not writeable
# ...
